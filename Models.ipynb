# %% [markdown]
# # Analyzing the performance of models on the same dataset

# %%
# !nvidia-smi
# Out:
# Wed Dec 21 19:23:23 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray
#   Downloading ray-2.2.0-cp38-cp38-manylinux2014_x86_64.whl (57.4 MB)
#      |████████████████████████████████| 57.4 MB 1.2 MB/s
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.17.1-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 64.1 MB/s
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from ray) (6.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from ray) (2.23.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.8/dist-packages (from ray) (1.21.6)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray) (7.1.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.0.4)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.51.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray) (3.19.6)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray) (22.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray) (3.8.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.3)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray) (2.6.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 46.9 MB/s
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (5.10.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.11.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (1.24.3)
# Installing collected packages: distlib, virtualenv, ray
# Successfully installed distlib-0.3.6 ray-2.2.0 virtualenv-20.17.1

# %%
# importing the libraries

import pandas as pd
import numpy as np
import copy

# for visualization

import plotly.express as px
import matplotlib.pyplot as plt

# hypeparameter tuning

import ray
from ray import tune
from ray.tune.schedulers import HyperBandScheduler

# %%
# models

import statsmodels.api as sm
import sklearn.model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import xgboost

# %%
# dict used to convert state to abbrev

us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
# Reading the training data

data = pd.read_csv('state_data_2019_processed_training.csv')

states = data.sitecode.unique()

# %%
# Creating the training/testing sets

state_data_t = []

state_data_test = []

seed = 100

for state in states:

    state_data = data[data.sitecode == state]
    X_s = state_data.iloc[:,:-1]
    y_s = state_data.iloc[:,-1]
    X_tr, X_val, y_tr, y_val = sklearn.model_selection.train_test_split(
        X_s, y_s, test_size=0.4, random_state=seed, stratify=y_s)
    X_val, X_te, y_val, y_te = sklearn.model_selection.train_test_split(
        X_val, y_val, test_size=0.5, random_state=seed, stratify=y_val)
    state_data_t.append([X_tr, X_val, y_tr, y_val])
    state_data_test.append((X_te, y_te))

X_train, X_val, y_train, y_val = state_data_t[0]

for i in range(1, len(state_data_t)):
    X_t,X_v,y_t,y_v = state_data_t[i]
    X_train = pd.concat([X_train, X_t])
    y_train = pd.concat([y_train, y_t])
    X_val = pd.concat([X_val, X_v])
    y_val = pd.concat([y_val, y_v])

# %%
state_data_t

state_data_test
# Out:
# [(     sitecode   weight  stratum  PSU  age_12 years old or younger  \
#   4      Alaska  21.7647        2    2                            0
#   1193   Alaska   2.7846       11    7                            0
#   1438   Alaska   2.7164        7   12                            0
#   1742   Alaska   4.2704        7   11                            0
#   75     Alaska   2.8208        7   14                            0
#   ...       ...      ...      ...  ...                          ...
#   1066   Alaska   2.9296        7    1                            0
#   1649   Alaska   5.4174       13    5                            0
#   370    Alaska   5.8406       21    3                            0
#   248    Alaska  17.9232        2    2                            0
#   545    Alaska  33.0762       19    1                            0
#
#         age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   4                    0                 0                 0                 0
#   1193                 0                 0                 1                 0
#   1438                 0                 0                 0                 1
#   1742                 0                 0                 0                 0
#   75                   0                 1                 0                 0
#   ...                ...               ...               ...               ...
#   1066                 0                 1                 0                 0
#   1649                 0                 0                 0                 0
#   370                  0                 0                 1                 0
#   248                  0                 0                 1                 0
#   545                  0                 0                 0                 1
#
#         age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   4                    0  ...              0              0
#   1193                 0  ...              0              0
#   1438                 0  ...              0              0
#   1742                 1  ...              0              0
#   75                   0  ...              0              0
#   ...                ...  ...            ...            ...
#   1066                 0  ...              0              0
#   1649                 1  ...              0              0
#   370                  0  ...              0              0
#   248                  0  ...              0              0
#   545                  0  ...              0              0
#
#         qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   4                       0                    0                    0
#   1193                    0                    0                    0
#   1438                    0                    0                    0
#   1742                    0                    0                    0
#   75                      0                    0                    0
#   ...                   ...                  ...                  ...
#   1066                    0                    0                    0
#   1649                    0                    0                    0
#   370                     0                    0                    0
#   248                     0                    0                    0
#   545                     0                    0                    0
#
#         qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   4                       0                 0                 0
#   1193                    0                 0                 0
#   1438                    0                 0                 0
#   1742                    0                 0                 0
#   75                      0                 0                 0
#   ...                   ...               ...               ...
#   1066                    0                 0                 0
#   1649                    0                 0                 0
#   370                     0                 0                 0
#   248                     0                 0                 0
#   545                     0                 0                 0
#
#         qntransgender_1.0  qntransgender_2.0
#   4                     0                  0
#   1193                  0                  0
#   1438                  0                  0
#   1742                  0                  0
#   75                    0                  0
#   ...                 ...                ...
#   1066                  0                  0
#   1649                  0                  0
#   370                   0                  0
#   248                   0                  0
#   545                   0                  0
#
#   [374 rows x 367 columns], 4       0
#   1193    1
#   1438    0
#   1742    0
#   75      1
#          ..
#   1066    0
#   1649    1
#   370     0
#   248     0
#   545     0
#   Name: qn28, Length: 374, dtype: int64),
#  (     sitecode    weight  stratum  PSU  age_12 years old or younger  \
#   2780  Alabama  133.6534       20    2                            0
#   3083  Alabama   82.1359       10    1                            0
#   2411  Alabama  102.4562       22    1                            0
#   2825  Alabama   88.0188        5    2                            0
#   2930  Alabama   86.9172       10    2                            0
#   ...       ...       ...      ...  ...                          ...
#   2925  Alabama  115.8742        3    2                            0
#   2932  Alabama   82.3707       20    1                            0
#   2593  Alabama  153.1314       13    2                            0
#   2616  Alabama   83.0761        8    1                            0
#   3334  Alabama  123.1513       10    2                            0
#
#         age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   2780                 0                 1                 0                 0
#   3083                 0                 0                 0                 1
#   2411                 0                 0                 0                 1
#   2825                 0                 0                 1                 0
#   2930                 0                 0                 1                 0
#   ...                ...               ...               ...               ...
#   2925                 0                 0                 1                 0
#   2932                 0                 0                 1                 0
#   2593                 0                 0                 0                 0
#   2616                 0                 0                 0                 0
#   3334                 0                 0                 0                 0
#
#         age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   2780                 0  ...              0              0
#   3083                 0  ...              0              0
#   2411                 0  ...              0              0
#   2825                 0  ...              0              0
#   2930                 0  ...              0              0
#   ...                ...  ...            ...            ...
#   2925                 0  ...              0              0
#   2932                 0  ...              0              0
#   2593                 1  ...              0              0
#   2616                 1  ...              0              0
#   3334                 1  ...              0              0
#
#         qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   2780                    0                    0                    0
#   3083                    0                    0                    0
#   2411                    0                    0                    0
#   2825                    0                    0                    0
#   2930                    0                    0                    0
#   ...                   ...                  ...                  ...
#   2925                    0                    0                    0
#   2932                    0                    0                    0
#   2593                    0                    0                    0
#   2616                    0                    0                    0
#   3334                    0                    0                    0
#
#         qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   2780                    0                 0                 0
#   3083                    0                 0                 0
#   2411                    0                 0                 0
#   2825                    0                 0                 0
#   2930                    0                 0                 0
#   ...                   ...               ...               ...
#   2925                    0                 0                 0
#   2932                    0                 0                 0
#   2593                    0                 0                 0
#   2616                    0                 0                 0
#   3334                    0                 0                 0
#
#         qntransgender_1.0  qntransgender_2.0
#   2780                  0                  0
#   3083                  0                  0
#   2411                  0                  0
#   2825                  0                  0
#   2930                  0                  0
#   ...                 ...                ...
#   2925                  0                  0
#   2932                  0                  0
#   2593                  0                  0
#   2616                  0                  0
#   3334                  0                  0
#
#   [337 rows x 367 columns], 2780    0
#   3083    0
#   2411    0
#   2825    0
#   2930    0
#          ..
#   2925    0
#   2932    0
#   2593    0
#   2616    0
#   3334    0
#   Name: qn28, Length: 337, dtype: int64),
#  (      sitecode    weight  stratum  PSU  age_12 years old or younger  \
#   3647  Arkansas  139.1265        7    2                            0
#   4803  Arkansas   63.3851        4    2                            0
#   4445  Arkansas  114.9806        7    2                            0
#   4345  Arkansas    8.1810        2    1                            0
#   3688  Arkansas  149.2545       12    1                            0
#   ...        ...       ...      ...  ...                          ...
#   4108  Arkansas  112.4840        9    1                            0
#   4123  Arkansas  112.4840        9    1                            0
#   4665  Arkansas    6.8981        2    2                            0
#   3643  Arkansas   69.4915        7    2                            0
#   4184  Arkansas   93.4932        7    2                            0
#
#         age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   3647                 0                 0                 1                 0
#   4803                 0                 0                 0                 1
#   4445                 0                 1                 0                 0
#   4345                 0                 0                 0                 0
#   3688                 0                 0                 1                 0
#   ...                ...               ...               ...               ...
#   4108                 0                 0                 0                 0
#   4123                 0                 0                 0                 0
#   4665                 0                 0                 1                 0
#   3643                 0                 0                 1                 0
#   4184                 0                 0                 0                 0
#
#         age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   3647                 0  ...              0              0
#   4803                 0  ...              0              0
#   4445                 0  ...              0              0
#   4345                 0  ...              0              0
#   3688                 0  ...              0              0
#   ...                ...  ...            ...            ...
#   4108                 1  ...              0              0
#   4123                 1  ...              0              0
#   4665                 0  ...              0              0
#   3643                 0  ...              0              0
#   4184                 1  ...              0              0
#
#         qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   3647                    0                    0                    0
#   4803                    0                    0                    0
#   4445                    0                    0                    0
#   4345                    0                    0                    0
#   3688                    0                    0                    0
#   ...                   ...                  ...                  ...
#   4108                    0                    0                    0
#   4123                    0                    0                    0
#   4665                    0                    0                    0
#   3643                    0                    0                    0
#   4184                    0                    0                    0
#
#         qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   3647                    0                 0                 1
#   4803                    0                 0                 1
#   4445                    0                 0                 1
#   4345                    0                 0                 1
#   3688                    0                 0                 1
#   ...                   ...               ...               ...
#   4108                    0                 0                 1
#   4123                    0                 0                 1
#   4665                    0                 0                 1
#   3643                    0                 0                 1
#   4184                    0                 0                 1
#
#         qntransgender_1.0  qntransgender_2.0
#   3647                  0                  0
#   4803                  0                  0
#   4445                  0                  0
#   4345                  0                  0
#   3688                  0                  0
#   ...                 ...                ...
#   4108                  0                  0
#   4123                  0                  0
#   4665                  0                  0
#   3643                  0                  0
#   4184                  0                  0
#
#   [345 rows x 367 columns], 3647    0
#   4803    0
#   4445    0
#   4345    0
#   3688    0
#          ..
#   4108    0
#   4123    0
#   4665    0
#   3643    0
#   4184    0
#   Name: qn28, Length: 345, dtype: int64),
#  (     sitecode    weight  stratum  PSU  age_12 years old or younger  \
#   6750  Arizona  191.2880       16    1                            0
#   6360  Arizona  198.0122       15    1                            0
#   5492  Arizona  127.4942       10    1                            0
#   5985  Arizona  192.4122        9    2                            0
#   5771  Arizona  194.6456       15    2                            0
#   ...       ...       ...      ...  ...                          ...
#   6539  Arizona  241.1892       11    2                            0
#   6121  Arizona  150.2739        9    2                            0
#   5286  Arizona  157.4665        7    2                            1
#   6662  Arizona  228.2032        7    1                            0
#   5887  Arizona  152.7724        1    2                            0
#
#         age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   6750                 0                 0                 0                 0
#   6360                 0                 0                 1                 0
#   5492                 0                 0                 1                 0
#   5985                 0                 0                 0                 0
#   5771                 0                 0                 0                 1
#   ...                ...               ...               ...               ...
#   6539                 0                 0                 0                 0
#   6121                 0                 1                 0                 0
#   5286                 0                 0                 0                 0
#   6662                 0                 0                 0                 0
#   5887                 0                 0                 0                 0
#
#         age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   6750                 0  ...              0              0
#   6360                 0  ...              0              0
#   5492                 0  ...              0              0
#   5985                 0  ...              0              0
#   5771                 0  ...              0              0
#   ...                ...  ...            ...            ...
#   6539                 1  ...              0              0
#   6121                 0  ...              0              0
#   5286                 0  ...              0              0
#   6662                 1  ...              0              0
#   5887                 1  ...              0              0
#
#         qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   6750                    0                    0                    0
#   6360                    0                    0                    0
#   5492                    0                    0                    0
#   5985                    0                    0                    0
#   5771                    0                    0                    0
#   ...                   ...                  ...                  ...
#   6539                    0                    0                    0
#   6121                    0                    0                    0
#   5286                    0                    0                    0
#   6662                    0                    0                    0
#   5887                    0                    0                    0
#
#         qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   6750                    0                 0                 0
#   6360                    0                 0                 0
#   5492                    0                 0                 0
#   5985                    0                 0                 0
#   5771                    0                 0                 0
#   ...                   ...               ...               ...
#   6539                    0                 0                 0
#   6121                    0                 0                 0
#   5286                    0                 0                 0
#   6662                    0                 0                 0
#   5887                    0                 0                 0
#
#         qntransgender_1.0  qntransgender_2.0
#   6750                  0                  0
#   6360                  0                  0
#   5492                  0                  0
#   5985                  0                  0
#   5771                  0                  0
#   ...                 ...                ...
#   6539                  0                  0
#   6121                  0                  0
#   5286                  0                  0
#   6662                  0                  0
#   5887                  0                  0
#
#   [305 rows x 367 columns], 6750    0
#   6360    0
#   5492    0
#   5985    0
#   5771    0
#          ..
#   6539    0
#   6121    1
#   5286    0
#   6662    0
#   5887    0
#   Name: qn28, Length: 305, dtype: int64),
#  (        sitecode     weight  stratum  PSU  age_12 years old or younger  \
#   7181  California   562.8275       11    1                            0
#   7241  California   856.7199        8    2                            0
#   6999  California  1276.7765       10    2                            0
#   7169  California   898.0788        6    2                            0
#   7301  California   636.2398       12    1                            0
#   ...          ...        ...      ...  ...                          ...
#   7699  California   626.8046       10    2                            0
#   7841  California   591.6503        4    1                            0
#   6854  California  1174.9490        7    2                            0
#   7654  California  1696.4935        8    2                            0
#   7538  California  1197.0792        4    1                            0
#
#         age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   7181                 0                 0                 0                 0
#   7241                 0                 0                 0                 0
#   6999                 0                 0                 1                 0
#   7169                 0                 0                 0                 0
#   7301                 0                 0                 0                 0
#   ...                ...               ...               ...               ...
#   7699                 0                 0                 0                 0
#   7841                 0                 0                 0                 0
#   6854                 0                 1                 0                 0
#   7654                 0                 0                 0                 1
#   7538                 0                 0                 0                 1
#
#         age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   7181                 1  ...              0              0
#   7241                 1  ...              0              0
#   6999                 0  ...              0              0
#   7169                 1  ...              0              0
#   7301                 0  ...              0              0
#   ...                ...  ...            ...            ...
#   7699                 1  ...              0              0
#   7841                 1  ...              0              0
#   6854                 0  ...              0              0
#   7654                 0  ...              0              0
#   7538                 0  ...              0              0
#
#         qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   7181                    0                    0                    0
#   7241                    0                    0                    0
#   6999                    0                    0                    0
#   7169                    0                    0                    0
#   7301                    0                    0                    0
#   ...                   ...                  ...                  ...
#   7699                    0                    0                    0
#   7841                    0                    0                    0
#   6854                    0                    0                    0
#   7654                    0                    0                    0
#   7538                    0                    0                    0
#
#         qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   7181                    0                 0                 1
#   7241                    0                 0                 1
#   6999                    0                 0                 1
#   7169                    0                 0                 1
#   7301                    0                 0                 1
#   ...                   ...               ...               ...
#   7699                    0                 0                 1
#   7841                    0                 0                 1
#   6854                    0                 0                 1
#   7654                    0                 0                 1
#   7538                    0                 0                 1
#
#         qntransgender_1.0  qntransgender_2.0
#   7181                  0                  0
#   7241                  0                  0
#   6999                  0                  0
#   7169                  0                  0
#   7301                  0                  0
#   ...                 ...                ...
#   7699                  0                  0
#   7841                  0                  0
#   6854                  0                  0
#   7654                  0                  0
#   7538                  0                  0
#
#   [214 rows x 367 columns], 7181    0
#   7241    0
#   6999    0
#   7169    0
#   7301    0
#          ..
#   7699    0
#   7841    0
#   6854    0
#   7654    1
#   7538    0
#   Name: qn28, Length: 214, dtype: int64),
#  (      sitecode    weight  stratum  PSU  age_12 years old or younger  \
#   9180  Colorado  132.8057        2    1                            0
#   9030  Colorado  232.5205       11    1                            0
#   8443  Colorado  235.4295        4    2                            0
#   8689  Colorado  154.3348        1    2                            0
#   8244  Colorado  188.0166        6    2                            0
#   ...        ...       ...      ...  ...                          ...
#   8262  Colorado  179.1311        8    2                            0
#   9171  Colorado  202.8507        4    2                            0
#   8793  Colorado  154.0687       14    2                            0
#   8214  Colorado  234.7892       13    2                            0
#   9068  Colorado  129.8610        7    1                            0
#
#         age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   9180                 0                 0                 0                 0
#   9030                 0                 0                 0                 0
#   8443                 0                 0                 0                 0
#   8689                 0                 0                 1                 0
#   8244                 0                 0                 0                 1
#   ...                ...               ...               ...               ...
#   8262                 0                 0                 0                 1
#   9171                 0                 0                 0                 0
#   8793                 0                 0                 1                 0
#   8214                 0                 0                 0                 1
#   9068                 0                 0                 0                 0
#
#         age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   9180                 0  ...              0              0
#   9030                 1  ...              0              0
#   8443                 1  ...              0              0
#   8689                 0  ...              0              0
#   8244                 0  ...              0              0
#   ...                ...  ...            ...            ...
#   8262                 0  ...              0              0
#   9171                 1  ...              0              0
#   8793                 0  ...              0              0
#   8214                 0  ...              0              0
#   9068                 1  ...              0              0
#
#         qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   9180                    0                    0                    0
#   9030                    0                    0                    0
#   8443                    0                    0                    0
#   8689                    0                    0                    0
#   8244                    0                    0                    0
#   ...                   ...                  ...                  ...
#   8262                    0                    0                    0
#   9171                    0                    0                    0
#   8793                    0                    0                    0
#   8214                    0                    0                    0
#   9068                    0                    0                    0
#
#         qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   9180                    0                 0                 0
#   9030                    0                 0                 0
#   8443                    0                 0                 0
#   8689                    0                 0                 0
#   8244                    0                 0                 0
#   ...                   ...               ...               ...
#   8262                    0                 0                 0
#   9171                    0                 0                 0
#   8793                    0                 0                 0
#   8214                    0                 0                 0
#   9068                    0                 0                 0
#
#         qntransgender_1.0  qntransgender_2.0
#   9180                  0                  1
#   9030                  0                  1
#   8443                  0                  1
#   8689                  0                  1
#   8244                  0                  1
#   ...                 ...                ...
#   8262                  0                  1
#   9171                  0                  1
#   8793                  0                  1
#   8214                  0                  1
#   9068                  0                  1
#
#   [268 rows x 367 columns], 9180    0
#   9030    0
#   8443    0
#   8689    0
#   8244    0
#          ..
#   8262    0
#   9171    0
#   8793    0
#   8214    0
#   9068    0
#   Name: qn28, Length: 268, dtype: int64),
#  (          sitecode    weight  stratum  PSU  age_12 years old or younger  \
#   10738  Connecticut   93.0063        9    2                            0
#   10132  Connecticut   57.0412        8    2                            0
#   10998  Connecticut   71.2797       13    1                            0
#   9559   Connecticut   88.8506       13    2                            0
#   9996   Connecticut  115.9447       13    2                            0
#   ...            ...       ...      ...  ...                          ...
#   11166  Connecticut   95.2708       15    1                            0
#   10787  Connecticut   73.4767        1    2                            0
#   9625   Connecticut  116.5902        6    2                            0
#   10558  Connecticut  109.3276        7    1                            0
#   9661   Connecticut   73.2729        5    1                            0
#
#          age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   10738                 0                 0                 0                 1
#   10132                 0                 0                 0                 0
#   10998                 0                 0                 0                 0
#   9559                  0                 0                 1                 0
#   9996                  0                 0                 0                 0
#   ...                 ...               ...               ...               ...
#   11166                 0                 0                 0                 0
#   10787                 0                 0                 0                 1
#   9625                  0                 0                 1                 0
#   10558                 0                 0                 1                 0
#   9661                  0                 0                 0                 1
#
#          age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   10738                 0  ...              0              0
#   10132                 0  ...              0              0
#   10998                 1  ...              0              0
#   9559                  0  ...              0              0
#   9996                  1  ...              0              0
#   ...                 ...  ...            ...            ...
#   11166                 0  ...              0              0
#   10787                 0  ...              0              0
#   9625                  0  ...              0              0
#   10558                 0  ...              0              0
#   9661                  0  ...              0              0
#
#          qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   10738                    0                    0                    0
#   10132                    0                    0                    0
#   10998                    0                    0                    0
#   9559                     0                    0                    0
#   9996                     0                    0                    0
#   ...                    ...                  ...                  ...
#   11166                    0                    0                    0
#   10787                    0                    0                    0
#   9625                     0                    0                    0
#   10558                    0                    0                    0
#   9661                     0                    0                    0
#
#          qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   10738                    0                 0                 1
#   10132                    0                 0                 1
#   10998                    0                 0                 1
#   9559                     0                 0                 1
#   9996                     0                 0                 1
#   ...                    ...               ...               ...
#   11166                    0                 0                 0
#   10787                    0                 0                 1
#   9625                     0                 0                 1
#   10558                    0                 0                 0
#   9661                     0                 1                 0
#
#          qntransgender_1.0  qntransgender_2.0
#   10738                  0                  0
#   10132                  0                  0
#   10998                  0                  0
#   9559                   0                  0
#   9996                   0                  0
#   ...                  ...                ...
#   11166                  0                  0
#   10787                  0                  0
#   9625                   0                  0
#   10558                  0                  0
#   9661                   0                  0
#
#   [401 rows x 367 columns], 10738    0
#   10132    0
#   10998    0
#   9559     0
#   9996     0
#           ..
#   11166    0
#   10787    0
#   9625     0
#   10558    0
#   9661     0
#   Name: qn28, Length: 401, dtype: int64),
#  (      sitecode    weight  stratum  PSU  age_12 years old or younger  \
#   13913  Florida  136.0613       29    1                            0
#   13451  Florida  223.3230       20    1                            0
#   12462  Florida  114.2843        1    2                            0
#   12826  Florida  272.6060       26    2                            0
#   15609  Florida  126.4284       38    1                            0
#   ...        ...       ...      ...  ...                          ...
#   13374  Florida  167.0770       16    1                            0
#   14299  Florida   89.0304       18    2                            0
#   15357  Florida  250.9716       27    2                            0
#   15715  Florida  153.4775        9    1                            0
#   14873  Florida  188.8189        3    2                            0
#
#          age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   13913                 0                 0                 1                 0
#   13451                 0                 0                 0                 0
#   12462                 0                 0                 0                 1
#   12826                 0                 0                 0                 0
#   15609                 0                 0                 0                 0
#   ...                 ...               ...               ...               ...
#   13374                 0                 0                 0                 0
#   14299                 0                 0                 1                 0
#   15357                 0                 0                 0                 0
#   15715                 0                 0                 0                 0
#   14873                 0                 0                 0                 1
#
#          age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   13913                 0  ...              0              0
#   13451                 0  ...              0              0
#   12462                 0  ...              0              0
#   12826                 1  ...              0              0
#   15609                 1  ...              0              0
#   ...                 ...  ...            ...            ...
#   13374                 0  ...              0              0
#   14299                 0  ...              0              0
#   15357                 1  ...              0              0
#   15715                 1  ...              0              0
#   14873                 0  ...              0              0
#
#          qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   13913                    0                    0                    0
#   13451                    0                    0                    0
#   12462                    0                    0                    0
#   12826                    0                    0                    0
#   15609                    0                    0                    0
#   ...                    ...                  ...                  ...
#   13374                    0                    0                    0
#   14299                    0                    0                    0
#   15357                    0                    0                    0
#   15715                    0                    0                    0
#   14873                    0                    0                    0
#
#          qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   13913                    0                 0                 0
#   13451                    0                 0                 0
#   12462                    0                 0                 0
#   12826                    0                 0                 0
#   15609                    0                 0                 0
#   ...                    ...               ...               ...
#   13374                    0                 0                 0
#   14299                    0                 0                 0
#   15357                    0                 0                 0
#   15715                    0                 0                 0
#   14873                    0                 0                 0
#
#          qntransgender_1.0  qntransgender_2.0
#   13913                  0                  1
#   13451                  0                  1
#   12462                  0                  1
#   12826                  0                  0
#   15609                  0                  1
#   ...                  ...                ...
#   13374                  0                  1
#   14299                  0                  1
#   15357                  0                  1
#   15715                  0                  1
#   14873                  0                  1
#
#   [964 rows x 367 columns], 13913    0
#   13451    0
#   12462    0
#   12826    0
#   15609    0
#           ..
#   13374    0
#   14299    0
#   15357    0
#   15715    0
#   14873    0
#   Name: qn28, Length: 964, dtype: int64),
#  (      sitecode   weight  stratum  PSU  age_12 years old or younger  \
#   16789  Georgia  34.0691       17    1                            0
#   18650  Georgia   6.5479        5    3                            0
#   16554  Georgia  18.6788        9    2                            0
#   16901  Georgia  13.6364       14    1                            0
#   18457  Georgia  12.9264        7    4                            0
#   ...        ...      ...      ...  ...                          ...
#   19183  Georgia  34.0369       16    2                            0
#   17021  Georgia  20.4217        4    6                            0
#   18654  Georgia  14.9111       12    1                            0
#   17796  Georgia   8.5507        8    5                            1
#   16628  Georgia  62.6484       19    2                            0
#
#          age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   16789                 0                 0                 0                 1
#   18650                 0                 0                 0                 1
#   16554                 0                 0                 1                 0
#   16901                 0                 0                 0                 1
#   18457                 0                 0                 1                 0
#   ...                 ...               ...               ...               ...
#   19183                 0                 0                 0                 0
#   17021                 0                 0                 0                 1
#   18654                 0                 0                 0                 1
#   17796                 0                 0                 0                 0
#   16628                 0                 0                 1                 0
#
#          age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   16789                 0  ...              0              0
#   18650                 0  ...              0              0
#   16554                 0  ...              0              0
#   16901                 0  ...              0              0
#   18457                 0  ...              0              0
#   ...                 ...  ...            ...            ...
#   19183                 1  ...              0              0
#   17021                 0  ...              0              0
#   18654                 0  ...              0              0
#   17796                 0  ...              0              0
#   16628                 0  ...              0              0
#
#          qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   16789                    0                    0                    0
#   18650                    0                    0                    0
#   16554                    0                    0                    0
#   16901                    0                    0                    0
#   18457                    0                    0                    0
#   ...                    ...                  ...                  ...
#   19183                    0                    0                    0
#   17021                    0                    0                    0
#   18654                    0                    0                    0
#   17796                    0                    0                    0
#   16628                    0                    0                    0
#
#          qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   16789                    1                 0                 0
#   18650                    1                 0                 0
#   16554                    1                 0                 0
#   16901                    1                 0                 0
#   18457                    1                 0                 0
#   ...                    ...               ...               ...
#   19183                    1                 0                 0
#   17021                    1                 0                 0
#   18654                    1                 0                 0
#   17796                    1                 0                 0
#   16628                    1                 0                 0
#
#          qntransgender_1.0  qntransgender_2.0
#   16789                  0                  0
#   18650                  0                  0
#   16554                  0                  0
#   16901                  0                  0
#   18457                  0                  0
#   ...                  ...                ...
#   19183                  0                  0
#   17021                  0                  0
#   18654                  0                  0
#   17796                  0                  0
#   16628                  0                  0
#
#   [723 rows x 367 columns], 16789    0
#   18650    0
#   16554    0
#   16901    0
#   18457    0
#           ..
#   19183    0
#   17021    0
#   18654    0
#   17796    0
#   16628    0
#   Name: qn28, Length: 723, dtype: int64),
#  (      sitecode   weight  stratum  PSU  age_12 years old or younger  \
#   23252   Hawaii  16.8303       18    1                            0
#   21620   Hawaii   7.1706       26    7                            0
#   23251   Hawaii  25.9576       18    1                            0
#   23173   Hawaii   1.7365        9    6                            0
#   22462   Hawaii   1.5483       22   17                            0
#   ...        ...      ...      ...  ...                          ...
#   19871   Hawaii   2.9734       26    1                            0
#   23810   Hawaii   1.7365        9    6                            0
#   20872   Hawaii   3.8722       24   16                            0
#   24242   Hawaii   3.5790       24   18                            0
#   24391   Hawaii   1.6633       21   11                            0
#
#          age_13 years old  age_14 years old  age_15 years old  age_16 years old  \
#   23252                 0                 0                 0                 1
#   21620                 0                 0                 0                 0
#   23251                 0                 0                 0                 1
#   23173                 0                 0                 1                 0
#   22462                 0                 1                 0                 0
#   ...                 ...               ...               ...               ...
#   19871                 0                 1                 0                 0
#   23810                 0                 0                 0                 1
#   20872                 0                 0                 0                 1
#   24242                 0                 0                 0                 0
#   24391                 0                 0                 0                 0
#
#          age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   23252                 0  ...              0              0
#   21620                 1  ...              0              0
# ...
#
#   [840 rows x 367 columns], 100999    0
#   100980    0
#   102855    0
#   102944    0
#   102500    0
#            ..
#   100738    0
#   102881    0
#   101428    1
#   103017    0
#   102304    0
#   Name: qn28, Length: 840, dtype: int64),
#  (       sitecode  weight  stratum  PSU  age_12 years old or younger  \
#   114635  Vermont  1.3236       64    2                            0
#   119758  Vermont  1.3506        1    2                            0
#   116577  Vermont  1.1178       33    1                            0
#   110381  Vermont  1.4516        1    1                            0
#   106580  Vermont  1.1792       30    2                            0
#   ...         ...     ...      ...  ...                          ...
#   114541  Vermont  1.0963       30    1                            0
#   112671  Vermont  1.4704       11    2                            0
#   106752  Vermont  1.2820        5    2                            0
#   113000  Vermont  1.8563       41    1                            0
#   121456  Vermont  1.3393       31    2                            0
#
#           age_13 years old  age_14 years old  age_15 years old  \
#   114635                 0                 1                 0
#   119758                 0                 0                 0
#   116577                 0                 0                 1
#   110381                 0                 0                 0
#   106580                 0                 0                 1
#   ...                  ...               ...               ...
#   114541                 0                 1                 0
#   112671                 0                 0                 0
#   106752                 0                 0                 1
#   113000                 0                 0                 0
#   121456                 0                 0                 0
#
#           age_16 years old  age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   114635                 0                 0  ...              1              0
#   119758                 1                 0  ...              0              1
#   116577                 0                 0  ...              1              0
#   110381                 1                 0  ...              1              0
#   106580                 0                 0  ...              1              0
#   ...                  ...               ...  ...            ...            ...
#   114541                 0                 0  ...              1              0
#   112671                 0                 1  ...              0              1
#   106752                 0                 0  ...              1              0
#   113000                 0                 1  ...              1              0
#   121456                 0                 1  ...              1              0
#
#           qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   114635                    0                    0                    0
#   119758                    0                    0                    0
#   116577                    0                    0                    0
#   110381                    0                    0                    0
#   106580                    0                    0                    0
#   ...                     ...                  ...                  ...
#   114541                    0                    0                    0
#   112671                    0                    0                    0
#   106752                    0                    0                    0
#   113000                    0                    0                    0
#   121456                    0                    0                    0
#
#           qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   114635                    0                 0                 0
#   119758                    0                 0                 0
#   116577                    0                 0                 0
#   110381                    0                 0                 0
#   106580                    0                 0                 0
#   ...                     ...               ...               ...
#   114541                    0                 0                 0
#   112671                    0                 0                 0
#   106752                    0                 0                 0
#   113000                    0                 0                 0
#   121456                    0                 0                 0
#
#           qntransgender_1.0  qntransgender_2.0
#   114635                  0                  1
#   119758                  0                  1
#   116577                  0                  1
#   110381                  0                  1
#   106580                  0                  1
#   ...                   ...                ...
#   114541                  0                  1
#   112671                  0                  1
#   106752                  0                  1
#   113000                  0                  1
#   121456                  0                  1
#
#   [3699 rows x 367 columns], 114635    0
#   119758    0
#   116577    0
#   110381    0
#   106580    0
#            ..
#   114541    0
#   112671    0
#   106752    0
#   113000    0
#   121456    0
#   Name: qn28, Length: 3699, dtype: int64),
#  (         sitecode    weight  stratum  PSU  age_12 years old or younger  \
#   124271  Wisconsin   95.6958        2    1                            0
#   123674  Wisconsin  149.3754       22    2                            0
#   124307  Wisconsin  131.3712        8    1                            0
#   124133  Wisconsin  190.3887       17    2                            0
#   123462  Wisconsin  112.7623       12    1                            0
#   ...           ...       ...      ...  ...                          ...
#   123526  Wisconsin  112.7623       12    1                            0
#   123979  Wisconsin  222.5335        6    1                            0
#   123775  Wisconsin  175.4529        5    2                            0
#   124194  Wisconsin  183.8236       18    1                            0
#   124480  Wisconsin  152.0299       22    2                            0
#
#           age_13 years old  age_14 years old  age_15 years old  \
#   124271                 0                 1                 0
#   123674                 0                 0                 1
#   124307                 0                 1                 0
#   124133                 0                 0                 0
#   123462                 0                 1                 0
#   ...                  ...               ...               ...
#   123526                 0                 1                 0
#   123979                 0                 0                 0
#   123775                 0                 0                 0
#   124194                 0                 0                 0
#   124480                 0                 0                 1
#
#           age_16 years old  age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   124271                 0                 0  ...              0              0
#   123674                 0                 0  ...              0              0
#   124307                 0                 0  ...              0              0
#   124133                 0                 0  ...              0              0
#   123462                 0                 0  ...              0              0
#   ...                  ...               ...  ...            ...            ...
#   123526                 0                 0  ...              0              0
#   123979                 0                 1  ...              0              0
#   123775                 1                 0  ...              0              0
#   124194                 0                 0  ...              0              0
#   124480                 0                 0  ...              0              0
#
#           qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   124271                    0                    0                    0
#   123674                    0                    0                    0
#   124307                    0                    0                    0
#   124133                    0                    0                    0
#   123462                    0                    0                    0
#   ...                     ...                  ...                  ...
#   123526                    0                    0                    0
#   123979                    0                    0                    0
#   123775                    0                    0                    0
#   124194                    0                    0                    0
#   124480                    0                    0                    0
#
#           qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   124271                    0                 0                 0
#   123674                    0                 0                 0
#   124307                    0                 0                 0
#   124133                    0                 0                 0
#   123462                    0                 0                 0
#   ...                     ...               ...               ...
#   123526                    0                 0                 0
#   123979                    0                 0                 0
#   123775                    0                 0                 0
#   124194                    0                 0                 0
#   124480                    0                 0                 0
#
#           qntransgender_1.0  qntransgender_2.0
#   124271                  0                  1
#   123674                  0                  1
#   124307                  0                  1
#   124133                  0                  1
#   123462                  0                  1
#   ...                   ...                ...
#   123526                  0                  1
#   123979                  0                  1
#   123775                  0                  1
#   124194                  0                  1
#   124480                  0                  1
#
#   [332 rows x 367 columns], 124271    0
#   123674    0
#   124307    0
#   124133    0
#   123462    0
#            ..
#   123526    0
#   123979    0
#   123775    0
#   124194    0
#   124480    0
#   Name: qn28, Length: 332, dtype: int64),
#  (             sitecode    weight  stratum  PSU  age_12 years old or younger  \
#   126236  West Virginia   97.6797       10    1                            0
#   125121  West Virginia   62.6704       13    2                            0
#   125504  West Virginia  113.4023        8    1                            0
#   125824  West Virginia   38.9799        5    1                            0
#   126146  West Virginia  168.8031        7    1                            0
#   ...               ...       ...      ...  ...                          ...
#   125936  West Virginia   59.9694       10    1                            0
#   125727  West Virginia   50.2226        4    2                            0
#   125832  West Virginia   21.3461        5    1                            0
#   125170  West Virginia   50.3601        8    2                            0
#   125992  West Virginia   37.9956        9    2                            0
#
#           age_13 years old  age_14 years old  age_15 years old  \
#   126236                 0                 0                 0
#   125121                 0                 1                 0
#   125504                 0                 0                 0
#   125824                 0                 0                 1
#   126146                 0                 0                 0
#   ...                  ...               ...               ...
#   125936                 0                 0                 0
#   125727                 0                 0                 1
#   125832                 0                 0                 1
#   125170                 0                 0                 1
#   125992                 0                 0                 0
#
#           age_16 years old  age_17 years old  ...  qnsunburn_1.0  qnsunburn_2.0  \
#   126236                 0                 0  ...              0              0
#   125121                 0                 0  ...              0              0
#   125504                 0                 1  ...              0              0
#   125824                 0                 0  ...              0              0
#   126146                 0                 1  ...              0              0
#   ...                  ...               ...  ...            ...            ...
#   125936                 1                 0  ...              0              0
#   125727                 0                 0  ...              0              0
#   125832                 0                 0  ...              0              0
#   125170                 0                 0  ...              0              0
#   125992                 1                 0  ...              0              0
#
#           qnconcentrating_1.0  qnconcentrating_2.0  qncurrentasthma_1.0  \
#   126236                    0                    0                    0
#   125121                    0                    0                    0
#   125504                    0                    0                    0
#   125824                    0                    0                    0
#   126146                    0                    0                    0
#   ...                     ...                  ...                  ...
#   125936                    0                    0                    0
#   125727                    0                    0                    0
#   125832                    0                    0                    0
#   125170                    0                    0                    0
#   125992                    0                    0                    0
#
#           qncurrentasthma_2.0  qnwheresleep_1.0  qnwheresleep_2.0  \
#   126236                    0                 0                 0
#   125121                    0                 0                 0
#   125504                    0                 0                 0
#   125824                    0                 0                 0
#   126146                    0                 0                 0
#   ...                     ...               ...               ...
#   125936                    0                 0                 0
#   125727                    0                 0                 0
#   125832                    0                 0                 0
#   125170                    0                 0                 0
#   125992                    0                 0                 0
#
#           qntransgender_1.0  qntransgender_2.0
#   126236                  0                  0
#   125121                  0                  0
#   125504                  0                  0
#   125824                  0                  0
#   126146                  0                  0
#   ...                   ...                ...
#   125936                  0                  0
#   125727                  0                  0
#   125832                  0                  0
#   125170                  0                  0
#   125992                  0                  0
#
#   [242 rows x 367 columns], 126236    0
#   125121    0
#   125504    0
#   125824    0
#   126146    0
#            ..
#   125936    0
#   125727    0
#   125832    0
#   125170    0
#   125992    0
#   Name: qn28, Length: 242, dtype: int64)]

# %%
# functions for visualizing the results

def map(model, race = 'all', exclude = None, data = state_data_t):

    auc_all = pd.DataFrame({'state': [us_state_to_abbrev[s] for s in states], 'auc': np.zeros(len(states))})

    for i, state in enumerate(states):
        _, X_test, _, y_test = data[i]
        if(race != 'all'):
            if(race == 'black'):
                index = X_test['race4_Black or African American'] == 1
            if(race == 'hispanic'):
                index = X_test['race4_Hispanic/Latino'] == 1
            X_test = X_test.loc[index]
            y_test = y_test.loc[index]
        if(exclude != None):
            X_test = X_test.drop(columns = exclude)
        y_pred = model.predict_proba(X_test.iloc[:,4:])
        fpr, tpr,_ = metrics.roc_curve(y_test, y_pred[:,1])
        auc = metrics.auc(fpr,tpr)
        auc_all.iloc[i,1] = auc

    fig = px.choropleth(auc_all,
                        locations='state', 
                        locationmode="USA-states", 
                        scope="usa",
                        color='auc',
                        color_continuous_scale="Viridis_r",
                        range_color = [0.6,1] 
                        )
    return fig, auc_all

def count_race(data = state_data_t):
    race = pd.DataFrame({
        'others': np.zeros(len(states)),
        'black': np.zeros(len(states)),
        'hispanic': np.zeros(len(states)),
        'white': np.zeros(len(states)),
        'missing': np.zeros(len(states))
    }, index = states)
    for i, state in enumerate(states):
        _, X_test, _, _ = data[i]
        race.iloc[i,0] = X_test['race4_All other races'].sum()
        race.iloc[i,1] = X_test['race4_Black or African American'].sum()
        race.iloc[i,2] = X_test['race4_Hispanic/Latino'].sum()
        race.iloc[i,3] = X_test['race4_White'].sum()
        race.iloc[i,4] = X_test['race4_All other races'].count() - \
            race.iloc[i,0] - race.iloc[i,1] -race.iloc[i,2] -race.iloc[i,3]
    
    return race

# %% [markdown]
# ## Logisitc Model

# %%
logistic_model = LogisticRegression(
    penalty='l2',
    max_iter=200
)
logistic_model = logistic_model.fit(X_train.iloc[:,4:], y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
logistic_model_map, logistic_auc = map(logistic_model)

# %%
logistic_model_map.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bb1c3025-f5c8-47ad-be3f-c61401deb5ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb1c3025-f5c8-47ad-be3f-c61401deb5ef")) {                    Plotly.newPlot(                        "bb1c3025-f5c8-47ad-be3f-c61401deb5ef",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"state=%{location}<br>auc=%{z}<extra></extra>","locationmode":"USA-states","locations":["AK","AL","AR","AZ","CA","CO","CT","FL","GA","HI","IA","ID","IL","KS","KY","LA","ME","MI","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OK","PA","RI","SC","SD","TN","TX","UT","VA","VT","WI","WV"],"name":"","z":[0.6763157894736843,0.8536396489416623,0.8509306803594352,0.8460356847453622,0.7582474226804123,0.886281969985204,0.9087941628264209,0.8898233569334192,0.8019967020361343,0.8430658399052837,0.8879464285714287,0.8631603998096145,0.8318612493977838,0.9369488536155203,0.8640711902113459,0.7692691029900333,0.7988059043842257,0.8864236758973602,0.8861439312567132,0.8117079735336997,0.8526308250572956,0.8772338772338772,0.6806722689075629,0.8248235782482358,0.9129154983653477,0.8854961832061069,0.873552159969817,0.86,0.8312578472326413,0.8827974276527332,0.8408354922279793,0.6697416974169741,0.8421237693389593,0.8602499399182889,0.7892654147780416,0.7908289241622575,0.8853877046648131,0.886794992596581,0.9085224542859566,0.8628707893413776,0.8667002012072434],"type":"choropleth"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0 ...

# %% [markdown]
# ## Random Forest Model

# %%
# !pip install tune_sklearn
# !pip install hpbandster ConfigSpace
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tune_sklearn
#   Downloading tune_sklearn-0.4.5-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 125 kB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from tune_sklearn) (1.7.3)
# Requirement already satisfied: ray[tune]>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from tune_sklearn) (2.2.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from tune_sklearn) (1.0.2)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.8/dist-packages (from tune_sklearn) (1.21.6)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (1.51.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (1.0.4)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (22.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (3.8.2)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (7.1.2)
# Requirement already satisfied: virtualenv>=20.0.24 in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (20.17.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (2.23.0)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (1.3.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (4.3.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (3.19.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (1.3.5)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 14.7 MB/s
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from ray[tune]>=2.0.0->tune_sklearn) (0.8.10)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray[tune]>=2.0.0->tune_sklearn) (2.6.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray[tune]>=2.0.0->tune_sklearn) (0.3.6)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[tune]>=2.0.0->tune_sklearn) (5.10.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray[tune]>=2.0.0->tune_sklearn) (0.19.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray[tune]>=2.0.0->tune_sklearn) (3.11.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ray[tune]>=2.0.0->tune_sklearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->ray[tune]>=2.0.0->tune_sklearn) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->ray[tune]>=2.0.0->tune_sklearn) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->ray[tune]>=2.0.0->tune_sklearn) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->ray[tune]>=2.0.0->tune_sklearn) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->ray[tune]>=2.0.0->tune_sklearn) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->ray[tune]>=2.0.0->tune_sklearn) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->tune_sklearn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->tune_sklearn) (3.1.0)
# Installing collected packages: tensorboardX, tune-sklearn
# Successfully installed tensorboardX-2.5.1 tune-sklearn-0.4.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hpbandster
#   Downloading hpbandster-0.7.4.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 144 kB/s
# Collecting ConfigSpace
#   Downloading ConfigSpace-0.6.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 35.6 MB/s
# Collecting Pyro4
#   Downloading Pyro4-4.82-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 12.3 MB/s
# Collecting serpent
#   Downloading serpent-1.41-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from hpbandster) (1.21.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.8/dist-packages (from hpbandster) (0.12.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from hpbandster) (1.7.3)
# Collecting netifaces
#   Downloading netifaces-0.11.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (33 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.8/dist-packages (from ConfigSpace) (0.29.32)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.8/dist-packages (from ConfigSpace) (3.0.9)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from ConfigSpace) (4.4.0)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.8/dist-packages (from statsmodels->hpbandster) (1.3.5)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.8/dist-packages (from statsmodels->hpbandster) (0.5.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.21->statsmodels->hpbandster) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.21->statsmodels->hpbandster) (2022.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5->statsmodels->hpbandster) (1.15.0)
# Building wheels for collected packages: hpbandster
#   Building wheel for hpbandster (setup.py) ... done
#   Created wheel for hpbandster: filename=hpbandster-0.7.4-py3-none-any.whl size=80008 sha256=8bc4bb576c668b498fd5d19992c0283fb1ed4b0225d9d4a33f1e251f50b1560d
#   Stored in directory: /root/.cache/pip/wheels/f6/42/dd/82bd75284b37e199206b84c6c5a057499687e6fa530674d43e
# Successfully built hpbandster
# Installing collected packages: serpent, Pyro4, netifaces, ConfigSpace, hpbandster
# Successfully installed ConfigSpace-0.6.0 Pyro4-4.82 hpbandster-0.7.4 netifaces-0.11.0 serpent-1.41

# %%
# Hyperparameter tuning using grid search

from tune_sklearn import TuneSearchCV
from tune_sklearn import TuneGridSearchCV

params = {
    'max_depth': [10,20,30,40],
    'min_samples_leaf' : [5,10,15,20],
    'min_samples_split': [10,20,30,40],
    'max_features' : [40,80,120,160],
}

# %%
tune_grid_search = TuneGridSearchCV(
    RandomForestClassifier(
        n_estimators = 200,
        random_state = seed, 
        criterion = 'gini'
        ),
    params,
    scoring = 'roc_auc',
    verbose=2,
    n_jobs = -1,
    use_gpu=True,
    early_stopping="MedianStoppingRule",
    max_iters=10
)

result_grid = tune_grid_search.fit(X_train.iloc[:,4:], y_train)
# Out:
# 2022-12-21 19:28:23,000	INFO worker.py:1538 -- Started a local Ray instance.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2022-12-21 22:58:18</td></tr>
# <tr><td>Running for: </td><td>03:29:49.42        </td></tr>
# <tr><td>Memory:      </td><td>2.8/12.7 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using MedianStoppingRule: num_stopped=144.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/7.42 GiB heap, 0.0/3.71 GiB objects (0.0/1.0 accelerator_type:T4)
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#   ... 154 more trials not shown (6 PAUSED, 9 PENDING, 137 TERMINATED)
#
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc             </th><th style="text-align: right;">  max_depth</th><th style="text-align: right;">  max_features</th><th style="text-align: right;">  min_samples_leaf</th><th style="text-align: right;">  min_samples_split</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  split0_test_score</th><th style="text-align: right;">  split1_test_score</th><th style="text-align: right;">  split2_test_score</th></tr>
# </thead>
# <tbody>
# <tr><td>_Trainable_a3761_00157</td><td>RUNNING   </td><td>172.28.0.12:4264</td><td style="text-align: right;">         20</td><td style="text-align: right;">           160</td><td style="text-align: right;">                10</td><td style="text-align: right;">                 30</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_a3761_00000</td><td>PAUSED    </td><td>172.28.0.12:4264</td><td style="text-align: right;">         10</td><td style="text-align: right;">            40</td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     4</td><td style="text-align: right;">         71.0115</td><td style="text-align: right;">           0.747724</td><td style="text-align: right;">           0.819298</td><td style="text-align: right;">           0.847283</td></tr>
# <tr><td>_Trainable_a3761_00001</td><td>PAUSED    </td><td>172.28.0.12:4264</td><td style="text-align: right;">         20</td><td style="text-align: right;">            40</td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     3</td><td style="text-align: right;">         78.9071</td><td style="text-align: right;">           0.740719</td><td style="text-align: right;">           0.80693 </td><td style="text-align: right;">           0.839777</td></tr>
# <tr><td>_Trainable_a3761_00002</td><td>PAUSED    </td><td>172.28.0.12:4264</td><td style="text-align: right;">         30</td><td style="text-align: right;">            40</td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     3</td><td style="text-align: right;">         83.9231</td><td style="text-align: right;">           0.736987</td><td style="text-align: right;">           0.806285</td><td style="text-align: right;">           0.839776</td></tr>
# <tr><td>_Trainable_a3761_00003</td><td>PAUSED    </td><td>172.28.0.12:4264</td><td style="text-align: right;">         40</td><td style="text-align: right;">            40</td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     3</td><td style="text-align: right;">         84.6289</td><td style="text-align: right;">           0.737918</td><td style="text-align: right;">           0.806538</td><td style="text-align: right;">           0.839999</td></tr>
# <tr><td>_Trainable_a3761_00004</td><td>PAUSED    </td><td>172.28.0.12:4264</td><td style="text-align: right;">         10</td><td style="text-align: right;">            80</td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     3</td><td style="text-align: right;">         84.9807</td><td style="text-align: right;">           0.73379 </td><td style="text-align: right;">           0.814938</td><td style="text-align: right;">           0.843574</td></tr>
# <tr><td>_Trainable_a3761_00005</td><td>PAUSED    </td><td>172.28.0.12:4264</td><td style="text-align: right;">         20</td><td style="text-align: right;">            80</td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     2</td><td style="text-align: right;">         92.9576</td><td style="text-align: right;">           0.726765</td><td style="text-align: right;">           0.800979</td><td style="text-align: right;">           0.835654</td></tr>
# <tr><td>_Trainable_a3761_00006</td><td>PAUSED    </td><td>172.28.0.12:4264</td><td style="text-align: right;">         30</td><td style="text-align: right;">            80</td><td style="text-align: right;">                 5</td><td style="text-align: right;">                 10</td><td style="text-align: right;">     2</td><td style="text-align: right;">         98.9647</td><td style="text-align: right;">           0.719146</td><td style="text-align: right;">           0.800184</td><td style="text-align: right;">           0.838892</td></tr>
# <tr><td>_Trainable_a3761_00158</td><td>PENDING   </td><td>                </td><td style="text-align: right;">         30</td><td style="text-align: right;">           160</td><td style="text-align: right;">                10</td><td style="text-align: right;">                 30</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_a3761_00159</td><td>PENDING   </td><td>                </td><td style="text-align: right;">         40</td><td style="text-align: right;">           160</td><td style="text-align: right;">                10</td><td style="text-align: right;">                 30</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_a3761_00160</td><td>PENDING   </td><td>                </td><td style="text-align: right;">         10</td><td style="text-align: right;">            40</td><td style="text-align: right;">                15</td><td style="text-align: right;">                 30</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td><td style="text-align: right;">                   </td></tr>
# <tr><td>_Trainable_a3761_00161</td><td>PENDING   </td><td>                </td><td style="text-align:
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name            </th><th style="text-align: right;">  average_test_score</th><th style="text-align: right;">  objective</th><th style="text-align: right;">  split0_test_score</th><th style="text-align: right;">  split1_test_score</th><th style="text-align: right;">  split2_test_score</th><th style="text-align: right;">  split3_test_score</th><th style="text-align: right;">  split4_test_score</th></tr>
# </thead>
# <tbody>
# <tr><td>_Trainable_a3761_00000</td><td style="text-align: right;">            0.820195</td><td style="text-align: right;">   0.820195</td><td style="text-align: right;">           0.747724</td><td style="text-align: right;">           0.819298</td><td style="text-align: right;">           0.847283</td><td style="text-align: right;">           0.806523</td><td style="text-align: right;">           0.880147</td></tr>
# <tr><td>_Trainable_a3761_00001</td><td style="text-align: right;">            0.809556</td><td style="text-align: right;">   0.809556</td><td style="text-align: right;">           0.740719</td><td style="text-align: right;">           0.80693 </td><td style="text-align: right;">           0.839777</td><td style="text-align: right;">           0.789074</td><td style="text-align: right;">           0.871279</td></tr>
# <tr><td>_Trainable_a3761_00002</td><td style="text-align: right;">            0.808084</td><td style="text-align: right;">   0.808084</td><td style="text-align: right;">           0.736987</td><td style="text-align: right;">           0.806285</td><td style="text-align: right;">           0.839776</td><td style="text-align: right;">           0.788677</td><td style="text-align: right;">           0.868694</td></tr>
# <tr><td>_Trainable_a3761_00003</td><td style="text-align: right;">            0.808606</td><td style="text-align: right;">   0.808606</td><td style="text-align: right;">           0.737918</td><td style="text-align: right;">           0.806538</td><td style="text-align: right;">           0.839999</td><td style="text-align: right;">           0.788767</td><td style="text-align: right;">           0.869806</td></tr>
# <tr><td>_Trainable_a3761_00004</td><td style="text-align: right;">            0.812495</td><td style="text-align: right;">   0.812495</td><td style="text-align: right;">           0.73379 </td><td style="text-align: right;">           0.814938</td><td style="text-align: right;">           0.843574</td><td style="text-align: right;">           0.789195</td><td style="text-align: right;">           0.880977</td></tr>
# <tr><td>_Trainable_a3761_00005</td><td style="text-align: right;">            0.801305</td><td style="text-align: right;">   0.801305</td><td style="text-align: right;">           0.726765</td><td style="text-align: right;">           0.800979</td><td style="text-align: right;">           0.835654</td><td style="text-align: right;">           0.77252 </td><td style="text-align: right;">           0.870605</td></tr>
# <tr><td>_Trainable_a3761_00006</td><td style="text-align: right;">            0.80162 </td><td style="text-align: right;">   0.80162 </td><td style="text-align: right;">           0.719146</td><td style="text-align: right;">           0.800184</td><td style="text-align: right;">           0.838892</td><td style="text-align: right;">           0.780082</td><td style="text-align: right;">           0.869795</td></tr>
# <tr><td>_Trainable_a3761_00007</td><td style="text-align: right;">            0.803198</td><td style="text-align: right;">   0.803198</td><td style="text-align: right;">           0.728192</td><td style="text-align: right;">           0.797745</td><td style="text-align: right;">           0.838094</td><td style="text-align: right;">           0.782902</td><td style="text-align: right;">           0.869055</td></tr>
# <tr><td>_Trainable_a3761_00008</td><td style="text-align: right;">            0.807904</td><td style="text-align: right;">   0.807904</td><td style="text-align: right;">           0.725033</td><td style="text-align: right;">           0.812814</td><td style="text-align: right;">           0.84325 </td><td style="text-align: right;">           0.777842</td><td style="text-align: right;">           0.880582</td></tr>
# <tr><td>_Trainable_a3761_00009</td><td style="text-align: right;">            0.790211</td><td style="text-align: right;">   0.790211</td><td style="text-align: right;">           0.722688</td><td style="text-align: right;">           0.793151</td><td style="text-align: right;">           0.822074</td><td style="text-align: right;">           0.750228</td><td style="text-align: right;">           0.862917</td></tr>
# <tr><td>_Trainable_a3761_00010</td><td style="text-align: right;">            0.789282</td><td style="text-align: right;">   0.789282</td><td style="text-align: right;">           0.718958</td><td style="text-align: right;">           0.791911</td><td style="text-align: right;">           0.8269  </td><td style="text-align: right;">           0.746179</td><td style="text-align: right;">           0.862463</td></tr>
# <tr><td>_Trainable_a3761_00011</td><td style="text-align: right;">            0.789878</td><td style="text-align: right;">   0.789878</td><td style="text-align: right;">           0.716984</td><td style="text-align: right;">           0.794698</td><td style="text-align: right;">           0.829987</td><td style="text-align: right;">           0.749931</td><td style="text-align: right;">           0.857792</td></tr>
# <tr><td>_Trainable_a3761_00012</td><td style="text-align: right;">            0.802966</td><td style="text-align: right;">   0.802966</td><td style="text-align: right;">           0.719801</td><td style="text-align: right;">           0.810439</td><td style="text-align: right;">           0.841972</td><td style="text-align: right;">           0.765031</td><td style="text-align: right;">           0.877588</td></tr>
# <tr><td>_Trainable_a3761_00013</td><td style="text-align: right;">            0.788488</td><td style="text-align: right;">   0.788488</td><td style="text-align: right;">           0.712586</td><td style="text-align: right;">           0.799682</td><td style="text-align: right;">           0.824211</td><td style="text-align: right;">           0.748631</td><td style="text-align: right;">           0.857332</td></tr>
# <tr><td>_Trainable_a3761_00014</td><td style="text-align: right;">            0.784141</td><td style="text-align: right;">   0.784141</td><td style="text-align: right;">           0.71215 </td><td style="text-align: right;">           0.788149</td><td style="text-align: right;">           0.824567</td><td style="text-align: right;">           0.743988</td><td style="text-align: right;">           0.851849</td></tr>
# <tr><td>_Trainable_a3761_00015</td><td style="text-align: right;">            0.784709</td><td style="text-align: right;">   0.784709</td><td style="text-align: right;">           0.709439</td><td style="text-align: right;">           0.792282</td><td style="text-align: right;">           0.825417</td><td style="text-align: right;">           0.746349</td><td style="text-align: right;">           0.850056</td></tr>
# <tr><td>_Trainable_a3761_00016</td><td style="text-align: right;">            0.826697</td><td style="text-align: right;">   0.826697</td><td style="text-align: right;">           0.772474</td><td style="text-align: right;">           0.818955</td><td style="text-align: right;">           0.848581</td><td style="text-align: right;">           0.814891</td><td style="text-align: right;">           0.878583</td></tr>
# <tr><td>_Trainable_a3761_00017</td><td style="text-align: right;">            0.81749 </td><td style="text-align: right;">   0.81749 </td><td style="text-align: right;">           0.759002</td><td style="text-align: right;">           0.815235</td><td style="text-align: right;">           0.842626</td><td style="text-align: right;">           0.796756</td><td style="
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.8/dist-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %%
pip install tune_search
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement tune_search (from versions: none)
# ERROR: No matching distribution found for tune_search

# %%
from tune_search import TuneSearchCV
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-1f788f1886f7> in <module>
# ----> 1 from tune_search import TuneSearchCV
#       2
#
# ModuleNotFoundError: No module named 'tune_search'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
tune_search = TuneSearchCV(
    RandomForestClassifier(
        n_estimators = 200,
        random_state = seed, 
        criterion = 'gini'
        ),
    params,
    scoring = 'roc_auc',
    verbose=2,
    n_jobs = -1,
    early_stopping="MedianStoppingRule",
    n_trials=20,
    max_iters=10,
    search_optimization="bohb"
)

result = tune_search.fit(X_train.iloc[:,4:], y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-822634154292> in <module>
# ----> 1 tune_search = TuneSearchCV(
#       2     RandomForestClassifier(
#       3         n_estimators = 200,
#       4         random_state = seed,
#       5         criterion = 'gini'
#
# NameError: name 'TuneSearchCV' is not defined

# %%
tune_grid_search.best_params

# %%
tune_search.best_params

# %%
rf_model = RandomForestClassifier(
    max_depth=30,
    max_features=40, 
    min_samples_leaf=20,
    min_samples_split=10,
    n_estimators=200,
    random_state = seed, 
    criterion = 'gini'
)
rf_model.fit(X_train.iloc[:,4:], y_train)

# %%
rf_model_map, rf_auc = map(rf_model)

# %%
rf_model_map.show()

# %% [markdown]
# ## XGBoost Model

# %% [markdown]
# ### Hyperparameter tuning

# %%
pip install ray
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ray
#   Downloading ray-2.2.0-cp38-cp38-manylinux2014_x86_64.whl (57.4 MB)
#      |████████████████████████████████| 57.4 MB 17.3 MB/s
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.8/dist-packages (from ray) (3.19.6)
# Collecting virtualenv>=20.0.24
#   Downloading virtualenv-20.17.1-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 25.8 MB/s
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.8/dist-packages (from ray) (1.21.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from ray) (6.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.8/dist-packages (from ray) (22.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from ray) (3.8.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.3)
# Requirement already satisfied: grpcio>=1.32.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.51.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from ray) (7.1.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from ray) (1.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from ray) (2.23.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.8/dist-packages (from ray) (1.3.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.8/dist-packages (from ray) (4.3.3)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.0.24->ray) (2.6.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 40.9 MB/s
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema->ray) (5.10.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema->ray) (3.11.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->ray) (3.0.4)
# Installing collected packages: distlib, virtualenv, ray
# Successfully installed distlib-0.3.6 ray-2.2.0 virtualenv-20.17.1

# %%
pip install tune
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tune
#   Downloading tune-0.1.2-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 4.2 MB/s
# Collecting fugue>=0.7.0
#   Downloading fugue-0.7.3-py3-none-any.whl (322 kB)
#      |████████████████████████████████| 322 kB 38.3 MB/s
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.8/dist-packages (from tune) (1.5.0)
# Collecting qpd>=0.3.1
#   Downloading qpd-0.3.4-py3-none-any.whl (187 kB)
#      |████████████████████████████████| 187 kB 62.4 MB/s
# Requirement already satisfied: pandas>=1.0.2 in /usr/local/lib/python3.8/dist-packages (from fugue>=0.7.0->tune) (1.3.5)
# Requirement already satisfied: pyarrow>=0.15.1 in /usr/local/lib/python3.8/dist-packages (from fugue>=0.7.0->tune) (9.0.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.8/dist-packages (from fugue>=0.7.0->tune) (1.4.45)
# Collecting fugue-sql-antlr>=0.1.1
#   Downloading fugue-sql-antlr-0.1.1.tar.gz (153 kB)
#      |████████████████████████████████| 153 kB 60.7 MB/s
# Collecting triad>=0.6.9
#   Downloading triad-0.7.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 7.7 MB/s
# Collecting adagio>=0.2.4
#   Downloading adagio-0.2.4-py3-none-any.whl (26 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from fugue>=0.7.0->tune) (2.11.3)
# Collecting antlr4-python3-runtime<4.12,>=4.11.1
#   Downloading antlr4_python3_runtime-4.11.1-py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 72.6 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.2->fugue>=0.7.0->tune) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.2->fugue>=0.7.0->tune) (2022.6)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.2->fugue>=0.7.0->tune) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0.2->fugue>=0.7.0->tune) (1.15.0)
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      |████████████████████████████████| 135 kB 53.8 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from fs->triad>=0.6.9->fugue>=0.7.0->tune) (57.4.0)
# Requirement already satisfied: appdirs~=1.4.3 in /usr/local/lib/python3.8/dist-packages (from fs->triad>=0.6.9->fugue>=0.7.0->tune) (1.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->fugue>=0.7.0->tune) (2.0.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.8/dist-packages (from sqlalchemy->fugue>=0.7.0->tune) (2.0.1)
# Building wheels for collected packages: fugue-sql-antlr
#   Building wheel for fugue-sql-antlr (setup.py) ... done
#   Created wheel for fugue-sql-antlr: filename=fugue_sql_antlr-0.1.1-py3-none-any.whl size=156689 sha256=1c5024fd591bd8ed95b7545fda9bc8b8c768ce01b9f3c1eade4e9828a4d59ab9
#   Stored in directory: /root/.cache/pip/wheels/11/2d/9b/bc17d29dddf7005595b00bcc9c4a91bcbfdb5338fcf14388e3
# Successfully built fugue-sql-antlr
# Installing collected packages: fs, triad, antlr4-python3-runtime, adagio, qpd, fugue-sql-antlr, fugue, tune
# Successfully installed adagio-0.2.4 antlr4-python3-runtime-4.11.1 fs-2.4.16 fugue-0.7.3 fugue-sql-antlr-0.1.1 qpd-0.3.4 triad-0.7.0 tune-0.1.2

# %%
import tune
import random
import xgboost as xgb
from ray.tune.integration.xgboost import TuneReportCheckpointCallback

def data_loader():
    return (X_train.iloc[:,4:].values,y_train.values), (X_val.iloc[:,4:].values,y_val.values)
def train_data(config,data):
    t1, t2 = data
    train_set = xgb.DMatrix(t1[0], label = t1[1])
    val_set = xgb.DMatrix(t2[0], label = t2[1])
    results = {}
    bst = xgb.train(
        config,
        train_set,
        num_boost_round = 50,
        evals = [(val_set, 'eval')],
        evals_result = results,
        verbose_eval = False,
        callbacks=[TuneReportCheckpointCallback(filename="model.xgb")]
    )

config = {
          "objective": "binary:logistic",
          "tree_method": "gpu_hist",
          "eval_metric": ["auc"],
          "max_depth": tune.randint(5,12),
          "min_child_weight": tune.randint(1,5),
          "colsample_bytree": tune.uniform(0.5, 1.0),
          "eta": tune.loguniform(1e-3, 1e-1),
          "reg_lambda": tune.uniform(0.1, 5),
          "reg_alpha": tune.uniform(0.1, 5),
          "n_estimators" : 200,
          "seed": 0
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-842fb772063f> in <module>
#      25           "tree_method": "gpu_hist",
#      26           "eval_metric": ["auc"],
# ---> 27           "max_depth": tune.randint(5,12),
#      28           "min_child_weight": tune.randint(1,5),
#      29           "colsample_bytree": tune.uniform(0.5, 1.0),
#
# AttributeError: module 'tune' has no attribute 'randint'

# %%
t1,t2 = data_loader()

analysis = tune.run(
    tune.with_parameters(train_data, data = (t1,t2)),
    resources_per_trial = {"gpu":1},
    config = config,
    num_samples = 50,
    metric='eval-auc',
    mode="max",
    stop={
        "eval-auc": 0.90,
        "training_iteration": 50
    },
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e4a89b8c8c00> in <module>
# ----> 1 t1,t2 = data_loader()
#       2
#       3 analysis = tune.run(
#       4     tune.with_parameters(train_data, data = (t1,t2)),
#       5     resources_per_trial = {"gpu":1},
#
# <ipython-input-10-842fb772063f> in data_loader()
#       5
#       6 def data_loader():
# ----> 7     return (X_train.iloc[:,4:].values,y_train.values), (X_val.iloc[:,4:].values,y_val.values)
#       8 def train_data(config,data):
#       9     t1, t2 = data
#
# NameError: name 'X_train' is not defined

# %%
t1,t2 = data_loader()

from ray.tune.schedulers import HyperBandScheduler

hyperband_scheduler = HyperBandScheduler(
    time_attr='training_iteration',
    metric='eval-auc',
    mode='max',
    max_t=50,
    reduction_factor=3)


analysis_hyper = tune.run(
    tune.with_parameters(train_data, data = (t1,t2)),
    resources_per_trial = {"gpu":1},
    config = config,
    num_samples = 50,
    scheduler = hyperband_scheduler
)

# %%
analysis.get_best_trial(metric = 'eval-auc', mode = 'max').last_result

# %%
analysis_hyper.get_best_trial(metric = 'eval-auc', mode = 'max').last_result

# %% [markdown]
# ### Helper Function

# %%
### Helper function

def map_xgb(model, race = 'all', exclude = None, data = state_data_t):

    auc_all = pd.DataFrame({'state': [us_state_to_abbrev[s] for s in states], 'auc': np.zeros(len(states))})

    for i, state in enumerate(states):
        _, X_test, _, y_test = data[i]
        if(race != 'all'):
            if(race == 'black'):
                index = X_test['race4_Black or African American'] == 1
            if(race == 'hispanic'):
                index = X_test['race4_Hispanic/Latino'] == 1
            X_test = X_test.loc[index]
            y_test = y_test.loc[index]
        if(exclude != None):
            X_test = X_test.drop(columns = exclude)
        X_test = xgb.DMatrix(X_test.iloc[:,4:].values)
        y_pred = model.predict(X_test)
        fpr, tpr,_ = metrics.roc_curve(y_test, y_pred)
        auc = metrics.auc(fpr,tpr)
        auc_all.iloc[i,1] = auc

    fig = px.choropleth(auc_all,
                        locations='state', 
                        locationmode="USA-states", 
                        scope="usa",
                        color='auc',
                        color_continuous_scale="Viridis_r",
                        range_color = [0.6,1] 
                        )
    return fig, auc_all

# %% [markdown]
# ### Model

# %%
config =  {{'objective': 'binary:logistic',
  'tree_method': 'gpu_hist',
  'eval_metric': ['auc'],
  'max_depth': 10,
  'min_child_weight': 3,
  'colsample_bytree': 0.5020551988135382,
  'eta': 0.029222812929186416,
  'reg_lambda': 0.36756709262675025,
  'reg_alpha': 3.7137701473201687,
  'n_estimators': 200,
  'seed': 0}}

# %%
train_set = xgb.DMatrix(X_train.iloc[:,4:].values,y_train.values)
val_set = xgb.DMatrix(X_val.iloc[:,4:].values,y_val.values)
results = {}
xgb_model = xgb.train(
    config,
    train_set,
    num_boost_round = 50,
    evals = [(val_set, 'eval')],
    evals_result = results,
    early_stopping_rounds=2,
)

# %%
xgb_model_map, xgb_auc = map_xgb(xgb_model)

# %%
xgb_model_map

# %% [markdown]
# ## Neural Network Model

# %% [markdown]
# ### Finding the best hyperparameters & structure

# %%
#Hyperparamter tuning

import tensorflow as tf
import math

from keras.models import Sequential
from keras.layers import Dense
from keras import initializers
from keras.callbacks import LearningRateScheduler
from keras.callbacks import EarlyStopping

from ray.tune.integration.keras import TuneReportCallback
from ray.tune.schedulers import HyperBandScheduler

def data_loader():
    return (X_train.iloc[:,4:].values,y_train.values), (X_val.iloc[:,4:].values,y_val.values)

def lr_step_decay(epoch, lr):
    drop_rate = 0.5
    epochs_drop = 5.0
    return 0.01 * math.pow(drop_rate, math.floor(epoch/epochs_drop))

def train_data(config,data):

    t1, t2 = data

    X_train = t1[0]
    y_train = t1[1]
    X_test = t2[0]
    y_test = t2[1]

    n_units = config['units']
    n_layers = config['layers']
    activation = config['activation']
    if(activation == 'tanh' or activation == 'sigmoid'):
        initializer = 'glorot_uniform'
    else:
        initializer = 'he_normal'

    model = Sequential()

    model.add(Dense(units = n_units, 
                    input_dim=X_train.shape[1], 
                    activation= activation,
                    kernel_initializer= initializer, 
                    name='h1'))
    
    for i in range(2, n_layers + 1):
        model.add(Dense(units= n_units, 
                        activation= activation,
                        kernel_initializer= initializer,  
                        name='h{}'.format(i)))
        
    model.add(Dense(units=1, activation='sigmoid', kernel_initializer=initializer, name='o'))

    model.compile(
        loss="binary_crossentropy", 
        optimizer=tf.keras.optimizers.Adam(
            learning_rate=0.01), 
        metrics=['AUC'])

    model.fit(
        X_train,
        y_train,
        batch_size=128,
        epochs=50,
        verbose=0,
        validation_data=(X_test, y_test),
        callbacks=[TuneReportCallback({
            "mean_auc": "val_auc"
            }),
            LearningRateScheduler(
                lr_step_decay, verbose=0
            ),
            EarlyStopping(
                monitor='val_auc', 
                patience=6
            )
        ])

# %% [markdown]
# ### GridSearch

# %%
t1,t2 = data_loader()

config = {
          'units': tune.grid_search([10, 20, 40, 80]),
          'layers': tune.grid_search([2, 4, 6, 8, 10]),
          'activation': tune.grid_search(['ReLU','tanh','sigmoid'])
}

analysis = tune.run(
    tune.with_parameters(train_data, data = (t1,t2)),
    resources_per_trial = {"gpu":1},
    config = config,
    metric='mean_auc',
    mode="max"
)

# %%
analysis.get_best_trial(metric = 'mean_auc', mode = 'max').last_result

# %% [markdown]
# ### Hyperband

# %%
t1,t2 = data_loader()

from ray.tune.schedulers import HyperBandScheduler

hyperband_scheduler = HyperBandScheduler(
    time_attr='training_iteration',
    metric='mean_auc',
    mode='max',
    max_t=50,
    reduction_factor=3)

config = {
          'units': tune.grid_search([10, 20, 40, 80]),
          'layers': tune.grid_search([2, 4, 6, 8, 10]),
          'activation': tune.grid_search(['ReLU','tanh','sigmoid'])
}

analysis_hyper = tune.run(
    tune.with_parameters(train_data, data = (t1,t2)),
    resources_per_trial = {"gpu":1},
    config = config,
    scheduler = hyperband_scheduler
)

# %%
analysis_hyper.get_best_trial(metric = 'mean_auc', mode = 'max').last_result

# %% [markdown]
# ### Model

# %% [markdown]
# AutoML

# %%
import h2o

# Start an H2O cluster
h2o.init()

# Load the data into an H2OFrame
data = h2o.import_file("/content/state_data_2019_processed_training.csv")

# Split the data into training and testing sets
train, test = data.split_frame(ratios=[0.8])

# Specify the target and predictor columns
x = data.columns[:-1]
y = data.columns[-1]

# Run the AutoML function
aml = h2o.automl.H2OAutoML(max_models=20, seed=1)
aml.train(x=x, y=y, training_frame=train, validation_frame=test)

# View the AutoML leaderboard
lb = aml.leaderboard
print(lb)

# Get the best model
best_model = h2o.get_model(lb[0, "model_id"])

# Make predictions on the test set using the best model
predictions = best_model.predict(test)
